# %%
pip install appJar
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from appJar import gui

# %%
# Out:
#   File "<ipython-input-11-8c77f6643f28>", line 12
#     class=model.predict(usr)
#          ^
# SyntaxError: invalid syntax

# %%
app = gui("Patent Classifier", "1000x500")

app.addLabel("title", "Welcome to XLPat")

app.playSound('C:\\Users\\mohit\\Desktop\\enter-the-publication-number1581190599.wav', wait= False)

app.setLabelBg("title", "red")

def press(button):

    if button == "Cancel":

        app.playSound('C:\\Users\\mohit\\Desktop\\thank-you-for-using-our1581198593.wav', wait= True)

        app.stop()

        

    else:

        usr = app.getEntry("Publication Number of Patent")
        file1 = open('/content/1.csv', 'r')
        csv_reader = csv.reader(file1)
        found = 0
        for row in csv_reader:
            if(str(row[0]) == str(usr)):
                t = row[1]
                break
            



       
        if t=='Alcohol':

            app.playSound('C:\\Users\\mohit\\Desktop\\alcohol1581200643.wav', wait= True)

        elif t=='Non-Alcohol':

            app.playSound('C:\\Users\\mohit\\Desktop\\non-alcohol1581200656.wav', wait= True)

        elif t=='Autonomous':

            app.playSound('C:\\Users\\mohit\\Desktop\\autonomous1581190726.wav', wait= True)

        elif t=='Non Autonomous':

            app.playSound('C:\\Users\\mohit\\Desktop\\non-autonomous1581190748.wav', wait= True)

        app.playSound('C:\\Users\\mohit\\Desktop\\processing-your1581190806.wav', wait= True)

        app.setLabel("l1", text = t)

app.setBg("orange")

app.setFont(18)

app.addLabelEntry("Publication Number of Patent")

app.addLabel('l1',text=' ')

app.addButtons(["Submit", "Cancel"], press)

app.go()
# Out:
# 2020-02-09 09:39:04,492 appJar:WARNING [799/_checkMode]: Interactive mode is not fully tested, some features might not work.
# 2020-02-09 09:39:04,502 appJar:WARNING [810/_checkMode]: iPython is not fully tested, some features might not work.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Anaconda\lib\site-packages\appJar\appjar.py", line 3783, in <lambda>
#     return lambda *args: funcName(param)
#   File "<ipython-input-18-db8079f2c96b>", line 23, in press
#     data=Patent(title='abc',url='https://patents.google.com/patent/' + str(usr) +'/en')
# NameError: name 'Patent' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Anaconda\lib\site-packages\appJar\appjar.py", line 3783, in <lambda>
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-eb42ca6e4af3> in <module>
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
model=torch.load('C:\\Users\\mohit\\Desktop\\final.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8bfe51911b00> in <module>
# ----> 1 model=torch.load('C:\\Users\\mohit\\Desktop\\final.pth')
#
# NameError: name 'torch' is not defined

# %%
import pypatent

# %%
pip install pypatent
# Out:
# ...
#   Stored in directory: C:\Users\mohit\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
app.stop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-11-4bb70ebce7f1> in <module>
# ----> 1 app.stop()
#
# C:\Anaconda\lib\site-packages\appJar\appjar.py in stop(self, event)
#    2142
#    2143             self.topLevel.quit()
# -> 2144             if not self.fastStop: self.topLevel.destroy()
#    2145             self.__class__.instantiated = False
#    2146             gui.info("--- GUI stopped ---")
#
# C:\Anaconda\lib\tkinter\__init__.py in destroy(self)
#    2060         end the application of this Tcl interpreter."""
#    2061         for c in list(self.children.values()): c.destroy()
# -> 2062         self.tk.call('destroy', self._w)
#    2063         Misc.destroy(self)
#    2064         global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed

# %%
pip install pytorch

# %%
data=pypatent.Patent(title='abc',url='https://patents.google.com/patent/US9028904B2/')

# %%
data.fetch_details()

# %%
data.claims
# Out:
# ['11',
#  ')',
#  'What is claimed is:',
#  '1. A method of preparing tofu or tofa, said method comprising:',
#  '(a) mixing, in powder form, a soybean powder prepared by a pulverization of dried soybeans, dextrin in an amount ranging from 20 parts to 40 parts by mass per 100 parts by mass of the said soybean powder, and magnesium carbonate in an amount ranging from 0.45 parts to 0.8 parts by mass per 100 parts by mass of the said soybean powder to form a soybean mixed powder;',
#  '(b) adding the soybean mixed powder to water;',
#  '(c) stirring the soybean mixed powder and water to dissolve the powder in the water to form a first solution;',
#  '(d) heating the first solution of (c) with stirring;',
#  '(e) stopping the heating;',
#  '(f) adding a coagulating agent to the heated solution of (e) with mixing to uniformly dissolve the coagulating agent therein to form a second solution; and,',
#  '(g) allowing the second solution of (f) to stand and coagulate.',
# ...
